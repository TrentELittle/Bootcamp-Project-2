# %%
import pandas as pd

# %%
file = "/Users/yusrakauppila/Bootcamp-Project-2/Resources/fire_locations.csv"

df = pd.read_csv(file)
df.head()
# Out:
#                         id     event_id  latitude  longitude type       area  \
# 0  SF11C173162715910433190  SF11E636803    39.151    -87.988   WF  39.500536
# 1  SF11C173162715910433190  SF11E636803    39.151    -87.988   WF  39.500536
# 2  SF11C173162715910433190  SF11E636803    39.151    -87.988   WF  39.500536
# 3  SF11C173162715910433190  SF11E636803    39.151    -87.988   WF  39.500536
# 4  SF11C173162715910433190  SF11E636803    39.151    -87.988   WF  39.500536
#
#             date_time  slope state  county  ...  \
# 0  202009180000-05:00   10.0    IL     NaN  ...
# 1  202009190000-05:00   10.0    IL     NaN  ...
# 2  202009200000-05:00   10.0    IL     NaN  ...
# 3  202009210000-05:00   10.0    IL     NaN  ...
# 4  202009220000-05:00   10.0    IL     NaN  ...
#
#                           sf_event_guid sf_hourly_area  \
# 0  027e27cf-c20e-4e5b-b3ce-7f52eca313f7            NaN
# 1  027e27cf-c20e-4e5b-b3ce-7f52eca313f7            NaN
# ...

# %%
columns = ["state", "latitude", "longitude", "date_time", "pm25", "pm10", "co", 
                    "co2", "ch4", "nox", "nh3", "so2", "voc"]

CA_df = df.loc[reduced_df["state"] == "CA", columns]
CA_df.head()
# Out:
#    state  latitude  longitude           date_time        pm25        pm10  \
# 12    CA    34.147   -116.909  202009180000-07:00  101.624063  119.916385
# 13    CA    34.147   -116.909  202009190000-07:00  101.624063  119.916385
# 14    CA    34.147   -116.909  202009200000-07:00  101.624063  119.916385
# 15    CA    34.147   -116.909  202009210000-07:00  101.624063  119.916385
# 16    CA    34.147   -116.909  202009220000-07:00  101.624063  119.916385
#
#              co           co2        ch4        nox        nh3       so2  \
# 12  1184.730785  13622.717438  57.841028  15.487941  19.431343  8.696066
# 13  1184.730785  13622.717438  57.841028  15.487941  19.431343  8.696066
# 14  1184.730785  13622.717438  57.841028  15.487941  19.431343  8.696066
# 15  1184.730785  13622.717438  57.841028  15.487941  19.431343  8.696066
# 16  1184.730785  13622.717438  57.841028  15.487941  19.431343  8.696066
#
#           voc
# 12  279.32545
# 13  279.32545
# 14  279.32545
# 15  279.32545
# ...
