# %%
import pandas as pd
import os
import requests
import json
import pprint
import matplotlib.pyplot as plt
import numpy as np
from config import (aqs_api_key)
from config import (email_address)
from sqlalchemy import create_engine

# https://aqs.epa.gov/aqsweb/documents/data_api.html#signup for api information
pp = pprint.PrettyPrinter(indent = 4)
states_url = "https://aqs.epa.gov/data/api/list/states"
parameters_url = "https://aqs.epa.gov/data/api/list/classes"
sample_data_url = "https://aqs.epa.gov/data/api/dailyData/byState"
p1 = {"email" : email_address, "key" : aqs_api_key}
from sqlalchemy import create_engine

# States to be used and their ID Codes, All in top 10 for worst congestion and traffic
California = "06"
cali_data = []

# %%
# Create a DataFrame for California and pull carbon monoxide data from API
cali_params = {"email" : email_address, "key" : aqs_api_key, "param" : "88101", 
          "bdate" : "20200901", "edate" : "20200915", "state" : California}

# Call to url
cali_response = requests.get(sample_data_url, params = cali_params).json()
cali_data.append(cali_response)

cali_df = pd.DataFrame(cali_data[0]["Data"])
cali_df.head()
# Out:
#   state_code county_code site_number parameter_code  poc   latitude  \
# 0         06         011        0007          88101    1  39.021221
# 1         06         011        0007          88101    1  39.021221
# 2         06         011        0007          88101    1  39.021221
# 3         06         011        0007          88101    1  39.021221
# 4         06         011        0007          88101    1  39.021221
#
#     longitude  datum                 parameter sample_duration  ...  \
# 0 -122.281803  WGS84  PM2.5 - Local Conditions          1 HOUR  ...
# 1 -122.281803  WGS84  PM2.5 - Local Conditions          1 HOUR  ...
# 2 -122.281803  WGS84  PM2.5 - Local Conditions          1 HOUR  ...
# 3 -122.281803  WGS84  PM2.5 - Local Conditions   24-HR BLK AVG  ...
# 4 -122.281803  WGS84  PM2.5 - Local Conditions   24-HR BLK AVG  ...
#
#   method_code                                             method  \
# 0         170  Met One BAM-1020 Mass Monitor w/VSCC - Beta At...
# 1         170  Met One BAM-1020 Mass Monitor w/VSCC - Beta At...
# 2         170  Met One BAM-1020 Mass Monitor w/VSCC - Beta At...
# 3         170  Met One BAM-1020 Mass Monitor w/VSCC - Beta At...
# 4         170  Met One BAM-1020 Mass Monitor w/VSCC - Beta At...
#
#             local_site_name  \
# 0  Cortina Indian Rancheria
# 1  Cortina Indian Rancheria
# 2  Cortina Indian Rancheria
# 3  Cortina Indian Rancheria
# 4  Cortina Indian Rancheria
#
#                                         site_address       state  county  \
# 0  CORTINA INDIAN RANCHERIA, SPRING VALLEY RD, WI...  California  Colusa
# 1  CORTINA INDIAN RANCHERIA, SPRING VALLEY RD, WI...  California  Colusa
# 2  CORTINA INDIAN RANCHERIA, SPRING VALLEY RD, WI...  California  Colusa
# 3  CORTINA INDIAN RANCHERIA, SPRING VALLEY RD, WI...  California  Colusa
# 4  CORTINA INDIAN RANCHERIA, SPRING VALLEY RD, WI...  California  Colusa
#
#                        city  cbsa_code  cbsa  date_of_last_change
# 0  Cortina Indian Rancheria       None  None           2020-09-16
# 1  Cortina Indian Rancheria       None  None           2020-09-16
# 2  Cortina Indian Rancheria       None  None           2020-09-16
# 3  Cortina Indian Rancheria       None  None           2020-09-16
# 4  Cortina Indian Rancheria       None  None           2020-09-16
#
# [5 rows x 31 columns]

# %%
clean_cali_df=cali_df.drop(["state_code", "county_code","site_number","parameter_code","datum","cbsa_code","poc","method_code","local_site_name","event_type","validity_indicator","method_code"], axis=1)
clean_cali_df
# Out:
#       latitude   longitude                 parameter sample_duration  \
# 0    39.021221 -122.281803  PM2.5 - Local Conditions          1 HOUR
# 1    39.021221 -122.281803  PM2.5 - Local Conditions          1 HOUR
# 2    39.021221 -122.281803  PM2.5 - Local Conditions          1 HOUR
# 3    39.021221 -122.281803  PM2.5 - Local Conditions   24-HR BLK AVG
# 4    39.021221 -122.281803  PM2.5 - Local Conditions   24-HR BLK AVG
# ..         ...         ...                       ...             ...
# 208  39.021221 -122.281803  PM2.5 - Local Conditions   24-HR BLK AVG
# 209  39.021221 -122.281803  PM2.5 - Local Conditions   24-HR BLK AVG
# 210  39.021221 -122.281803  PM2.5 - Local Conditions          1 HOUR
# 211  39.021221 -122.281803  PM2.5 - Local Conditions          1 HOUR
# 212  39.021221 -122.281803  PM2.5 - Local Conditions          1 HOUR
#
#     pollutant_standard  date_local             units_of_measure  \
# 0                 None  2020-09-01  Micrograms/cubic meter (LC)
# 1                 None  2020-09-01  Micrograms/cubic meter (LC)
# 2                 None  2020-09-01  Micrograms/cubic meter (LC)
# 3    PM25 24-hour 2006  2020-09-01  Micrograms/cubic meter (LC)
# 4     PM25 Annual 2006  2020-09-01  Micrograms/cubic meter (LC)
# ..                 ...         ...                          ...
# 208  PM25 24-hour 2012  2020-09-14  Micrograms/cubic meter (LC)
# 209   PM25 Annual 2012  2020-09-14  Micrograms/cubic meter (LC)
# 210               None  2020-09-15  Micrograms/cubic meter (LC)
# 211               None  2020-09-15  Micrograms/cubic meter (LC)
# 212               None  2020-09-15  Micrograms/cubic meter (LC)
#
#      observation_count  observation_percent  arithmetic_mean  first_max_value  \
# 0                   23                100.0        38.739130             90.0
# 1                   24                100.0        41.166667             97.0
# 2                   24                100.0        41.166667             97.0
# 3                    1                100.0        38.700000             38.7
# 4                    1                100.0        38.700000             38.7
# ..                 ...                  ...              ...              ...
# 208                  1                100.0        83.100000             83.1
# 209                  1                100.0        83.100000             83.1
# 210                 10                 46.0        28.000000             58.0
# 211                 11                 46.0        26.909091             58.0
# 212                 11                 46.0        26.909091             58.0
#
#      first_max_hour    aqi                                             method  \
# 0                 1    NaN  Met One BAM-1020 Mass Monitor w/VSCC - Beta At...
# 1                 0    NaN  Met One BAM-1020 Mass Monitor w/VSCC - Beta At...
# 2                 0    NaN  Met One BAM-1020 Mass Monitor w/VSCC - Beta At...
# 3                 0  115.0  Met One BAM-1020 Mass Monitor w/VSCC - Beta At...
# 4                 0  115.0  Met One BAM-1020 Mass Monitor w/VSCC - Beta At...
# ..              ...    ...                                                ...
# 208               0  165.0  Met One BAM-1020 Mass Monitor w/VSCC - Beta At...
# 209               0  165.0  Met One BAM-1020 Mass Monitor w/VSCC - Beta At...
# 210              10    NaN  Met One BAM-1020 Mass Monitor w/VSCC - Beta At...
# 211              10    NaN  Met One BAM-1020 Mass Monitor w/VSCC - Beta At...
# 212              10    NaN  Met One BAM-1020 Mass Monitor w/VSCC - Beta At...
#
#                                           site_address       state  county  \
# 0    CORTINA INDIAN RANCHERIA, SPRING VALLEY RD, WI...  California  Colusa
# 1    CORTINA INDIAN RANCHERIA, SPRING VALLEY RD, WI...  California  Colusa
# 2    CORTINA INDIAN RANCHERIA, SPRING VALLEY RD, WI...  California  Colusa
# 3    CORTINA INDIAN RANCHERIA, SPRING VALLEY RD, WI...  California  Colusa
# 4    CORTINA INDIAN RANCHERIA, SPRING VALLEY RD, WI...  California  Colusa
# ..                                                 ...         ...     ...
# 208  CORTINA INDIAN RANCHERIA, SPRING VALLEY RD, WI...  California  Colusa
# 209  CORTINA INDIAN RANCHERIA, SPRING VALLEY RD, WI...  California  Colusa
# 210  CORTINA INDIAN RANCHERIA, SPRING VALLEY RD, WI...  California  Colusa
# 211  CORTINA INDIAN RANCHERIA, SPRING VALLEY RD, WI...  California  Colusa
# 212  CORTINA INDIAN RANCHERIA, SPRING VALLEY RD, WI...  California  Colusa
#
#                          city  cbsa date_of_last_change
# 0    Cortina Indian Rancheria  None          2020-09-16
# 1    Cortina Indian Rancheria  None          2020-09-16
# 2    Cortina Indian Rancheria  None          2020-09-16
# 3    Cortina Indian Rancheria  None          2020-09-16
# 4    Cortina Indian Rancheria  None          2020-09-16
# ..                        ...   ...                 ...
# 208  Cortina Indian Rancheria  None          2020-09-16
# 209  Cortina Indian Rancheria  None          2020-09-16
# 210  Cortina Indian Rancheria  None          2020-09-16
# 211  Cortina Indian Rancheria  None          2020-09-16
# 212  Cortina Indian Rancheria  None          2020-09-16
#
# [213 rows x 20 columns]

# %%
clean_cali_df=cali_df.drop(["state_code", "county_code","site_number","parameter_code","datum","cbsa_code","poc","method_code","local_site_name","event_type","validity_indicator","method_code"], axis=1)
clean_cali_df
# Out:
#       latitude   longitude                 parameter sample_duration  \
# 0    39.021221 -122.281803  PM2.5 - Local Conditions          1 HOUR
# 1    39.021221 -122.281803  PM2.5 - Local Conditions          1 HOUR
# 2    39.021221 -122.281803  PM2.5 - Local Conditions          1 HOUR
# 3    39.021221 -122.281803  PM2.5 - Local Conditions   24-HR BLK AVG
# 4    39.021221 -122.281803  PM2.5 - Local Conditions   24-HR BLK AVG
# ..         ...         ...                       ...             ...
# 208  39.021221 -122.281803  PM2.5 - Local Conditions   24-HR BLK AVG
# 209  39.021221 -122.281803  PM2.5 - Local Conditions   24-HR BLK AVG
# 210  39.021221 -122.281803  PM2.5 - Local Conditions          1 HOUR
# 211  39.021221 -122.281803  PM2.5 - Local Conditions          1 HOUR
# 212  39.021221 -122.281803  PM2.5 - Local Conditions          1 HOUR
#
#     pollutant_standard  date_local             units_of_measure  \
# 0                 None  2020-09-01  Micrograms/cubic meter (LC)
# 1                 None  2020-09-01  Micrograms/cubic meter (LC)
# 2                 None  2020-09-01  Micrograms/cubic meter (LC)
# 3    PM25 24-hour 2006  2020-09-01  Micrograms/cubic meter (LC)
# 4     PM25 Annual 2006  2020-09-01  Micrograms/cubic meter (LC)
# ..                 ...         ...                          ...
# 208  PM25 24-hour 2012  2020-09-14  Micrograms/cubic meter (LC)
# 209   PM25 Annual 2012  2020-09-14  Micrograms/cubic meter (LC)
# 210               None  2020-09-15  Micrograms/cubic meter (LC)
# 211               None  2020-09-15  Micrograms/cubic meter (LC)
# 212               None  2020-09-15  Micrograms/cubic meter (LC)
#
#      observation_count  observation_percent  arithmetic_mean  first_max_value  \
# 0                   23                100.0        38.739130             90.0
# 1                   24                100.0        41.166667             97.0
# 2                   24                100.0        41.166667             97.0
# 3                    1                100.0        38.700000             38.7
# 4                    1                100.0        38.700000             38.7
# ..                 ...                  ...              ...              ...
# 208                  1                100.0        83.100000             83.1
# 209                  1                100.0        83.100000             83.1
# 210                 10                 46.0        28.000000             58.0
# 211                 11                 46.0        26.909091             58.0
# 212                 11                 46.0        26.909091             58.0
#
#      first_max_hour    aqi                                             method  \
# 0                 1    NaN  Met One BAM-1020 Mass Monitor w/VSCC - Beta At...
# 1                 0    NaN  Met One BAM-1020 Mass Monitor w/VSCC - Beta At...
# 2                 0    NaN  Met One BAM-1020 Mass Monitor w/VSCC - Beta At...
# 3                 0  115.0  Met One BAM-1020 Mass Monitor w/VSCC - Beta At...
# 4                 0  115.0  Met One BAM-1020 Mass Monitor w/VSCC - Beta At...
# ..              ...    ...                                                ...
# 208               0  165.0  Met One BAM-1020 Mass Monitor w/VSCC - Beta At...
# 209               0  165.0  Met One BAM-1020 Mass Monitor w/VSCC - Beta At...
# 210              10    NaN  Met One BAM-1020 Mass Monitor w/VSCC - Beta At...
# 211              10    NaN  Met One BAM-1020 Mass Monitor w/VSCC - Beta At...
# 212              10    NaN  Met One BAM-1020 Mass Monitor w/VSCC - Beta At...
#
#                                           site_address       state  county  \
# 0    CORTINA INDIAN RANCHERIA, SPRING VALLEY RD, WI...  California  Colusa
# 1    CORTINA INDIAN RANCHERIA, SPRING VALLEY RD, WI...  California  Colusa
# 2    CORTINA INDIAN RANCHERIA, SPRING VALLEY RD, WI...  California  Colusa
# 3    CORTINA INDIAN RANCHERIA, SPRING VALLEY RD, WI...  California  Colusa
# 4    CORTINA INDIAN RANCHERIA, SPRING VALLEY RD, WI...  California  Colusa
# ..                                                 ...         ...     ...
# 208  CORTINA INDIAN RANCHERIA, SPRING VALLEY RD, WI...  California  Colusa
# 209  CORTINA INDIAN RANCHERIA, SPRING VALLEY RD, WI...  California  Colusa
# 210  CORTINA INDIAN RANCHERIA, SPRING VALLEY RD, WI...  California  Colusa
# 211  CORTINA INDIAN RANCHERIA, SPRING VALLEY RD, WI...  California  Colusa
# 212  CORTINA INDIAN RANCHERIA, SPRING VALLEY RD, WI...  California  Colusa
#
#                          city  cbsa date_of_last_change
# 0    Cortina Indian Rancheria  None          2020-09-16
# 1    Cortina Indian Rancheria  None          2020-09-16
# 2    Cortina Indian Rancheria  None          2020-09-16
# 3    Cortina Indian Rancheria  None          2020-09-16
# 4    Cortina Indian Rancheria  None          2020-09-16
# ..                        ...   ...                 ...
# 208  Cortina Indian Rancheria  None          2020-09-16
# 209  Cortina Indian Rancheria  None          2020-09-16
# 210  Cortina Indian Rancheria  None          2020-09-16
# 211  Cortina Indian Rancheria  None          2020-09-16
# 212  Cortina Indian Rancheria  None          2020-09-16
#
# [213 rows x 20 columns]

# %%
csv_file = "../Resources /fire_location.csv"
fire_data_df = pd.read_csv(csv_file)
fire_data_df.head()
# Out:
#                         id     event_id  latitude  longitude type       area  \
# 0  SF11C173162715910433190  SF11E636803    39.151    -87.988   WF  39.500536
# 1  SF11C173162715910433190  SF11E636803    39.151    -87.988   WF  39.500536
# 2  SF11C173162715910433190  SF11E636803    39.151    -87.988   WF  39.500536
# 3  SF11C173162715910433190  SF11E636803    39.151    -87.988   WF  39.500536
# 4  SF11C173162715910433190  SF11E636803    39.151    -87.988   WF  39.500536
#
#             date_time  slope state  county  ...  \
# 0  202009180000-05:00   10.0    IL     NaN  ...
# 1  202009190000-05:00   10.0    IL     NaN  ...
# 2  202009200000-05:00   10.0    IL     NaN  ...
# 3  202009210000-05:00   10.0    IL     NaN  ...
# 4  202009220000-05:00   10.0    IL     NaN  ...
#
#                           sf_event_guid sf_hourly_area  \
# 0  027e27cf-c20e-4e5b-b3ce-7f52eca313f7            NaN
# 1  027e27cf-c20e-4e5b-b3ce-7f52eca313f7            NaN
# 2  027e27cf-c20e-4e5b-b3ce-7f52eca313f7            NaN
# 3  027e27cf-c20e-4e5b-b3ce-7f52eca313f7            NaN
# 4  027e27cf-c20e-4e5b-b3ce-7f52eca313f7            NaN
#
#    sf_hourly_area_fraction  sf_hourly_flaming_fraction  sf_hourly_heat  \
# 0                      NaN                         NaN             NaN
# 1                      NaN                         NaN             NaN
# 2                      NaN                         NaN             NaN
# 3                      NaN                         NaN             NaN
# 4                      NaN                         NaN             NaN
#
#    sf_hourly_residual_fraction  sf_hourly_smolder_fraction  sf_server  \
# 0                          NaN                         NaN  tomcat-sf
# 1                          NaN                         NaN  tomcat-sf
# 2                          NaN                         NaN  tomcat-sf
# 3                          NaN                         NaN  tomcat-sf
# 4                          NaN                         NaN  tomcat-sf
#
#                  sf_stream_name  timezone
# 0  CWFIS-Hotspots+GroundReports      -6.0
# 1  CWFIS-Hotspots+GroundReports      -6.0
# 2  CWFIS-Hotspots+GroundReports      -6.0
# 3  CWFIS-Hotspots+GroundReports      -6.0
# 4  CWFIS-Hotspots+GroundReports      -6.0
#
# [5 rows x 76 columns]
